# %%
import xmltodict
import pandas as pd

# %%
xml_filedata = open('kh-muulraakhaasinkhaaekstrraaywan.xml').read()

ordered_dict = xmltodict.parse(xml_filedata)

# %%
ordered_dict
# Out:
# OrderedDict([('root',
#               OrderedDict([('entry',
#                             [OrderedDict([('PRICE_DATE', '21-DEC-18'),
#                                           ('PR_PROD_NAME',
#                                            'หัวมันสำปะหลังสดเชื้อแป้ง 25%(นอกโครงการ)'),
#                                           ('MARKET_NAME',
#                                            'บ.สงวนวงษ์อุตสาหกรรม จำกัด นครราชสีมา'),
#                                           ('PRICE_DAY', '2.55')]),
#                              OrderedDict([('PRICE_DATE', '21-DEC-18'),
#                                           ('PR_PROD_NAME',
#                                            'หัวมันสำปะหลังสดเชื้อแป้ง 25%(นอกโครงการ)'),
#                                           ('MARKET_NAME',
#                                            'โรงงานแป้งมันสำปะหลังครบุรี นครราชสีมา'),
#                                           ('PRICE_DAY', '2.55')]),
# ...
